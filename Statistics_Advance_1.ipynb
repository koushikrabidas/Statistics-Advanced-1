# %% [markdown]
# 1. What is a random variable in probability theory?
#     - In probability theory, a random variable is a function that assigns a numerical value to each possible outcome of a random experiment.

# %% [markdown]
# 2. What are the types of random variables?
#     - There are two types of random variable. One is Discrete random variable and the other one is Continuous random variable.

# %% [markdown]
# 3. Explain the difference between discrete and continuous distributions.
#     - Discrete distribution means the random variable takes countable values or finite values and it is done through Probability Mass Function. Where as continuous distribution means the random variable can take uncountably infinte values within an interval and it is done through Probability Density Function.

# %% [markdown]
# 4. What is a binomial distribution, and how is it used in probability?
#     - The binomial distribution is one of the most important discrete probability distribution in statistics and probability theory. It describes the number of successes in a fixed number of independent trials, each having the same probability of success.

# %% [markdown]
# 5.  What is the standard normal distribution, and why is it important?
#     - The standard normal distribution is a special case of the normal bell curve distribution. It is also called the Z-distribution because we often represent it with the Z-score. It is important because we can conver any normal distribution to a standard normal distribution.

# %% [markdown]
# 6. What is the Central Limit Theorem (CLT), and why is it critical in statistics?
#     - The Central Limit Theorem states that the distribution of sample means approaches a normal distribution as the sample size increases, regardless of the population's original distribution. The CLT is critical because it’s the reason we can use normal distribution methods for a wide range of problems, even when the original data isn’t normal.

# %% [markdown]
# 7. What is the significance of confidence intervals in statistical analysis?
#     - A confidence interval (CI) provides a range of values, derived from sample data, that is likely to contain the true population parameter with a certain level of confidence (e.g., 95%). It helps in Quantifies uncertainty, improves interpretation, guides decision making, used in hypothesis testing.

# %% [markdown]
# 8. What is the concept of expected value in a probability distribution?
#     - The expected value of a probability distribution is the long-run average or mean value you would expect to get if an experiment were repeated infinitely many times under the same conditions.

# %% [markdown]
# 9. Write a Python program to generate 1000 random numbers from a normal
# distribution with mean = 50 and standard deviation = 5. Compute its mean and standard
# deviation using NumPy, and draw a histogram to visualize the distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt

mean = 50
std_dev = 5
n_sample = 1000

data = np.random.normal(mean, std_dev, n_sample)

computed_mean = np.mean(data)
computed_std = np.std(data)

print(f"Computed Mean: {computed_mean:.2f}")
print(f"Computed Standard Deviation: {computed_std:.2f}")

plt.hist(data, bins = 30, color= "skyblue", edgecolor = "black", alpha = 0.7)
plt.title("Normal Distribution (mean = 50, std = 5)")
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True, linestyle = "--", alpha = 0.6)
plt.show()
# Out:
# Computed Mean: 50.03
# Computed Standard Deviation: 5.08

# %% [markdown]
# 10. You are working as a data analyst for a retail company. The company has
#     collected daily sales data for 2 years and wants you to identify the overall sales trend.
#
#
#     daily_sales = [220, 245, 210, 265, 230, 250, 260, 275, 240, 255,
#     235, 260, 245, 250, 225, 270, 265, 255, 250, 260]
#
#
#     Explain how you would apply the Central Limit Theorem to estimate the average sales
#     with a 95% confidence interval.
#
#
#     Write the Python code to compute the mean sales and its confidence interval.

# %%
import numpy as np
from scipy import stats

daily_sales = [220, 245, 210, 265, 230, 250, 260, 275, 240, 255,
               235, 260, 245, 250, 225, 270, 265, 255, 250, 260]

sales_array = np.array(daily_sales)

mean_sales = np.mean(sales_array)
std_sales = np.std(sales_array)

n = len(sales_array)

sem = std_sales / np.sqrt(n)

confidence = 0.95
t_crit = stats.t.ppf((1+confidence)/2, df = n-1)

lower_bound = mean_sales - t_crit * sem
upper_bound = mean_sales + t_crit * sem

print(f"Mean Sales: {mean_sales:.2f}")
print(f"95% Confidence Interval: ({lower_bound:.2f}, {upper_bound:.2f})")
# Out:
# Mean Sales: 248.25
# 95% Confidence Interval: (240.37, 256.13)
